# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # MODEL TRAINING

# %%
import numpy as np
import torch

# set seed for reproducibility
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
LABEL2ID = {"VICTIM": 0, "FACILITATOR": 1, "AGENT": 2, "CAMPAIGNER": 3, "OBJECTIVE": 4, "NEGATIVE_EFFECT": 5}
ID2LABEL = {0: "VICTIM", 1: "FACILITATOR", 2: "AGENT", 3: "CAMPAIGNER", 4: "OBJECTIVE", 5: "NEGATIVE_EFFECT"}

# %%
import json

# Path to your JSON file
train_dataset_path = '/content/drive/Shareddrives/PanClef2024/dataset/dataset_en_train.json'
test_dataset_path = '/content/drive/Shareddrives/PanClef2024/dataset/dataset_en_official_test_nolabels.json'

# Load JSON data into a variable
with open(train_dataset_path, 'r') as file:
    train_data_raw = json.load(file)

# train_data_raw

# %%
train_spans = []
train_clas = []
valid_test_spans = []
valid_test_clas = []
valid_spans = []
valid_clas = []
test_spans = []
test_clas = []

# %%
for entry in train_data_raw[:int(len(train_data_raw)*0.7)]:
  for annot in entry['annotations']:
    train_spans.append(annot['span_text'])
    train_clas.append(annot['category'])
for entry in train_data_raw[int(len(train_data_raw)*0.7):]:
  for annot in entry['annotations']:
    valid_test_spans.append(annot['span_text'])
    valid_test_clas.append(annot['category'])

# %%
print(len(train_spans))
print(len(valid_test_spans))
# Out:
# 15782
# 6871

# %%
for span in valid_test_spans[:int(len(valid_spans)*0.7)]:
  valid_spans.append(span)
for span in valid_test_spans[int(len(valid_spans)*0.7):]:
  test_spans.append(span)
for clas in valid_test_clas[:int(len(valid_spans)*0.7)]:
  valid_clas.append(clas)
for clas in valid_test_clas[int(len(valid_spans)*0.7):]:
  test_clas.append(clas)

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 859.3 kB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 727.7 kB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 718.0 kB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, pyarrow, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-16.1.0 requests-2.32.3 xxhash-3.4.1

# %%
from datasets import Dataset, DatasetDict


# train (80%), validation (10%), test (10%) split
# train_test_datasets = preprocessed_datasets['train'].train_test_split(test_size=0.2, seed=SEED, shuffle=True)
# validation_test_datasets = train_test_datasets['test'].train_test_split(test_size=0.5, seed=SEED, shuffle=True)

preprocessed_datasets = DatasetDict({
    'train': [[train_spans[i], train_clas[i]] for i in range(len(train_spans))],
    'validation': [[valid_spans[i], valid_clas[i]] for i in range(len(valid_spans))],
    'test':  [[test_spans[i], test_clas[i]] for i in range(len(test_spans))]
})
preprocessed_datasets
# Out:
# DatasetDict({
#     train: [['Australian Senator Malcolm Roberts', 'CAMPAIGNER'], ['the first politician', 'CAMPAIGNER'], ['I ’m deeply concerned that the push to vaccinate these children is nothing more than a dystopian experiment with unknown consequences', 'NEGATIVE_EFFECT'], ['to vaccinate these children', 'OBJECTIVE'], ['these children', 'VICTIM'], ['Rep. Louie Gohmert ( R - Texas )', 'CAMPAIGNER'], ['TheDefender', 'CAMPAIGNER'], ['childrenshealthdefense', 'CAMPAIGNER'], ['fda', 'AGENT'], ['eua', 'AGENT'], ['infants', 'VICTIM'], ['young - kids', 'VICTIM'], ['someone who died suddenly', 'VICTIM'], ['died suddenly', 'NEGATIVE_EFFECT'], ['brutal Chinese lockdowns', 'NEGATIVE_EFFECT'], ['the Communist government', 'AGENT'], ['forcefully locking people inside buildings', 'NEGATIVE_EFFECT'], ['death from Wuhan coronavirus ( COVID - 19 ) “ vaccine ” is not always an immediate thing', 'NEGATIVE_EFFECT'], ['Kirsch', 'CAMPAIGNER'], ['COVID “ vaccines ” also cause AIDS', 'NEGATIVE_EFFECT'], ['those who took jab', 'VICTIM'], ['are ticking timebombs , with each shot making it worse due to their infinite creation of spike proteins per the mRNA throughout the body', 'NEGATIVE_EFFECT'], ['Joe Biden', 'AGENT'], ['Americans', 'VICTIM'], ['has just tested positive for COVID after having had four vaccinations', 'NEGATIVE_EFFECT'], ['summit', 'CAMPAIGNER'], ['quadruple - vaxxed - biden', 'AGENT'], ['quadruple - vaxxed - biden - catches - covid', 'NEGATIVE_EFFECT'], ['[ DS ] TAPURIANS', 'AGENT'], ['[ DS ] TAPURIAN DLA - PIPER partner puppet agentur Harriet Lipkin in Washington DC', 'AGENT'], ['the [ DS ] TAPURIAN KHETA INDIAN RESERVATION SHAMANS', 'AGENT'], ['the [ DS ] TAPURIAN PEDOWOOD FILM DIRECTOR / ex - TAPURIAN BBC MONTY PYTHON actor Terry Gilliam with [ DS ] TAPURIAN AMERICAN PEDOVORE JOHNNY DEPP', 'AGENT'], ['the [ DS ] TAPURIAN MOSSAD / CIA post - assassination of " " righteous " " TAPURIAN John F Kennedy', 'AGENT'], ['[ DS ] TAPURIAN BIGPHARMA / CANCERINC', 'AGENT'], ['we as humanity', 'VICTIM'], ['FOREIGN PARTICLES FOUND IN THE BLOOD OF 94 % OF THE VACCINATED', 'NEGATIVE_EFFECT'], ['94 % OF THE VACCINATED', 'VICTIM'], ['Pfizer', 'AGENT'], ['Moderna', 'AGENT'], ['Of the 1,006 cases , 948 ( 94 . 23 % ) showed various alterations in the blood', 'NEGATIVE_EFFECT'], ['the manufacturers', 'AGENT'], ['Joe Biden ’s Commerce Secretary', 'AGENT'], ['millions of Americans', 'VICTIM'], ['summit', 'CAMPAIGNER'], ['biden - commerce - secretary', 'AGENT'], ['People', 'VICTIM'], ['to ARM ( WEAPONISE ) the bacteria [ eg Mycoplasma / Toxoplasmosis / Fungii etc ] in order to eat up the bad tissues', 'OBJECTIVE'], ['EXIT COVID - NEXT - RUSSIA IS BAD NARRATIVE - MSM IS FAKE NEWS - MSM IS - ENNEMY OF THE PEOPLE   SHARE ! ! https :// t . me / QNewsOfficialTV', 'X'], ['70 to 80 % of We The People', 'CAMPAIGNER'], ['We The People', 'CAMPAIGNER'], ['President Donald Trump', 'CAMPAIGNER'], ['100 % of local , state , and federal RINO Republican “ selected ” officials and candidates', 'FACILITATOR'], ['President Trump', 'CAMPAIGNER'], ['the RINO Republicans', 'FACILITATOR'], ['their ruling elite cronies', 'AGENT'], ['the RINO Republicans', 'FACILITATOR'], ['the “ Republicans ” who are NOT taking ACTION to FIX 2020 and get rid of the computer voting cheat machines', 'FACILITATOR'], ['The RINO Republicans', 'FACILITATOR'], ['the We The People', 'CAMPAIGNER'], ['Former State Department official David Asher', 'CAMPAIGNER'], ['former - state - department - investigator', 'CAMPAIGNER'], ['Q', 'CAMPAIGNER'], ['the Old Guard NWO', 'AGENT'], ['its stakeholders', 'AGENT'], ['the pharmaceutical and vaccine industries', 'AGENT'], ['a “ conspiracy theorist ”', 'CAMPAIGNER'], ['[ they ] programmed people to shame others who even DARE mention it , for YEARS', 'NEGATIVE_EFFECT'], ['to bring in the agenda', 'OBJECTIVE'], ['naturalnews', 'CAMPAIGNER'], ['some teachers', 'FACILITATOR'], ['your kids', 'VICTIM'], ['heroes who took their grievances directly to the people in DC who have been spittin ...
#     validation: []
#     test: [['to forcibly vaccinate people using the military and police', 'OBJECTIVE'], ['the military', 'FACILITATOR'], ['police', 'FACILITATOR'], ['Vaxxies are dying at such an unignorable rate that the completely corrupt , Pfizer funded CDC has to do " " an investigation " "', 'NEGATIVE_EFFECT'], ['Pfizer funded CDC', 'AGENT'], ['no Democrat in America', 'FACILITATOR'], ['Budget airline Ryanair', 'FACILITATOR'], ['summit', 'CAMPAIGNER'], ['all security forces', 'VICTIM'], ["FNC 's Carlson", 'CAMPAIGNER'], ['Teachers', 'FACILITATOR'], ['Tribalism', 'NEGATIVE_EFFECT'], ["We 've Reached Jonestown at This Point", 'NEGATIVE_EFFECT'], ['the CDC', 'AGENT'], ['DEATH only from the covid 19 Vaccine', 'NEGATIVE_EFFECT'], ['life threatening effects , disability or hospitalisation side effects', 'NEGATIVE_EFFECT'], ['THE NEW YELLOW VEST MOVEMENT', 'CAMPAIGNER'], ['the great populist anti - vaccine passport movement', 'CAMPAIGNER'], ['Nearly a million people', 'CAMPAIGNER'], ['demonstrators', 'CAMPAIGNER'], ['The demonstrators', 'CAMPAIGNER'], ['Macron', 'AGENT'], ['unvaccinated people', 'VICTIM'], ['unvaccinated people', 'VICTIM'], ['unvaccinated children', 'VICTIM'], ['unvaccinated people', 'VICTIM'], ['unvaccinated people', 'VICTIM'], ['the protest movement', 'CAMPAIGNER'], ['the Yellow Vests', 'CAMPAIGNER'], ['a majority of blue collar workers , small business owners , right wing populists , " " conspiracy theorists " " who have lost confidence in the government and the media', 'CAMPAIGNER'], ['the government', 'AGENT'], ['the media', 'FACILITATOR'], ['the government', 'AGENT'], ['summit', 'CAMPAIGNER'], ['Elon Musk', 'FACILITATOR'], ['Musk', 'FACILITATOR'], ['Deep State', 'AGENT'], ['to usher in the NWO and transhumanism agenda', 'OBJECTIVE'], ['the shot being very bad for our health', 'NEGATIVE_EFFECT'], ['BQQQQQQQM DEADLY VACCINES EXPOSED - Watch as truth bomb after truth bomb lands - THOUGHTS ?   SHARE ! ! https :// t . me / QNewsOfficialTV', 'X'], ['our souls', 'OBJECTIVE'], ['the soul of man', 'OBJECTIVE'], ['The ironic scarcity of happiness Mass contract killing sanctioned', 'NEGATIVE_EFFECT'], ['Cabaal', 'AGENT'], ['manufactured wars through constant lies', 'NEGATIVE_EFFECT'], ['funding - of all sides', 'OBJECTIVE'], ['victims', 'VICTIM'], ['Banksters', 'AGENT'], ['Profit making FIAT currency usuary system', 'OBJECTIVE'], ['undue persistent stress', 'NEGATIVE_EFFECT'], ['Corporates', 'AGENT'], ['government', 'AGENT'], ['to opress Pandemic nonsense lying stats', 'OBJECTIVE'], ['cycle of torment to ourselves', 'NEGATIVE_EFFECT'], ['unknowning crippled masses', 'VICTIM'], ['Doug Mubbant - Cools', 'CAMPAIGNER'], ['Dougtravellernd', 'CAMPAIGNER'], ['Aliens Or Demons', 'AGENT'], ["to deceive humanity into accepting demons as aliens from different planets and viewing them as ' higher beings ' as well as how the ' New Age ' movement", 'OBJECTIVE'], ['humanity', 'VICTIM'], ['their NWO agenda', 'OBJECTIVE'], ['Even After Being Fully Vaccinated , Many Still Wrestle With a Fear of Catching COVID - 19', 'NEGATIVE_EFFECT'], ['Since the start of the pandemic , Kit Breshears has been terrified of catching COVID - 19', 'NEGATIVE_EFFECT'], ['Kit Breshears', 'VICTIM'], ['Breshears', 'VICTIM'], ['Getting vaccinated did not magically change that', 'NEGATIVE_EFFECT'], ['For the past 13 months , Breshears has not stepped foot inside a store or restaurant , not even to pick up a takeout meal', 'NEGATIVE_EFFECT'], ['Breshears', 'VICTIM'], ['Any visits with family and friends have been over Zoom', 'NEGATIVE_EFFECT'], ['Even after receiving his second COVID - 19 shot earlier this month , Breshears has found it impossible to turn off his anxiety', 'NEGATIVE_EFFECT'], ['we end up getting a horrible variant that puts us right back to where we are', 'NEGATIVE_EFFECT'], ['Breshears , a communications director at a local university', 'VICTIM'], ['COVID1984chat', 'CAMPAIGNER'], ['BIG PHARMA', 'AGENT'], ['Big Pharma', 'AGENT'], ['to continue to get people vacc ...
# })

# %%
train_dataset = Dataset.from_dict({'text': train_spans, 'labels': train_clas})
valid_dataset = Dataset.from_dict({'text': valid_spans, 'labels': valid_clas})
test_dataset = Dataset.from_dict({'text': test_spans, 'labels': test_clas})

# Create DatasetDict
preprocessed_datasets = DatasetDict({
    'train': train_dataset,
    'validation': valid_dataset,
    'test': test_dataset
})

# %%
from transformers import AutoTokenizer

CHECKPOINT = 'distilbert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(CHECKPOINT)
tokenized_datasets = preprocessed_datasets.map(lambda batch: tokenizer(batch['text'], truncation=True), batched=True, remove_columns=['text'])
tokenized_datasets
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Map:   0%|          | 0/15782 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6871 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 15782
#     })
#     validation: Dataset({
#         features: ['labels'],
#         num_rows: 0
#     })
#     test: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 6871
#     })
# })

# %%
#randomly inserted this

from transformers import BertTokenizer, BertForSequenceClassification, AutoModelForSequenceClassification
import torch

# Define the checkpoint and labels
CHECKPOINT = "bert-base-uncased"
# LABEL2ID = {'LABEL_0': 0, 'LABEL_1': 1, 'LABEL_2': 2}  # Example label mapping
# ID2LABEL = {0: 'LABEL_0', 1: 'LABEL_1', 2: 'LABEL_2'}

# Load pre-trained model and tokenizer
tokenizer = BertTokenizer.from_pretrained(CHECKPOINT)
model = AutoModelForSequenceClassification.from_pretrained(
    CHECKPOINT,
    problem_type='multi_label_classification',
    num_labels=len(LABEL2ID),
    label2id=LABEL2ID,
    id2label=ID2LABEL,
)

# Save the model and tokenizer
save_directory = "./fine_tuned_model"
model.save_pretrained(save_directory)
tokenizer.save_pretrained(save_directory)
print(f"Model and tokenizer saved in {save_directory}")

# Load the saved model and tokenizer
loaded_model = BertForSequenceClassification.from_pretrained(save_directory)
loaded_tokenizer = BertTokenizer.from_pretrained(save_directory)
print("Model and tokenizer loaded successfully")

# Example usage
def classify_span(span_text):
    inputs = loaded_tokenizer(span_text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = loaded_model(**inputs)
    logits = outputs.logits
    predicted_class_id = logits.argmax().item()
    return predicted_class_id

# Example classification
span_text = "Example text to classify"
predicted_class = classify_span(span_text)
print(f"Predicted class: {predicted_class}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model and tokenizer saved in ./fine_tuned_model
# Model and tokenizer loaded successfully
# Predicted class: 3

# %%
from transformers import AutoModelForSequenceClassification

model = AutoModelForSequenceClassification.from_pretrained(
    CHECKPOINT,
    problem_type='multi_label_classification',
    num_labels=len(LABEL2ID),
    label2id=LABEL2ID,
    id2label=ID2LABEL,
)

save_directory = "./fine_tuned_model"

# Save the model
model.save_pretrained(save_directory)

# Save the tokenizer
tokenizer.save_pretrained(save_directory)

print(f"Model and tokenizer saved in {save_directory}")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model and tokenizer saved in ./fine_tuned_model

# %%
from transformers import DataCollatorWithPadding
from torch.utils.data import DataLoader

# get data collator for data loader
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# setup dataloaders with tokenized dataset
# to shuffle only be train for each epoch
# in 64 batch sizes with dynamic padding

dataloaders = {}
for dataset_type in tokenized_datasets.keys():
    dataloaders[dataset_type] = DataLoader(
        dataset=tokenized_datasets[dataset_type],
        batch_size=64,
        shuffle=(dataset_type == 'train'),
        collate_fn=data_collator,
    )

# %% [markdown]
# # EDIT LATER

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def preprocess_text(text):
    doc = nlp(text)
    sentences = list(doc.sents)
    spans = [(sent.start_char, sent.end_char, sent.text) for sent in sentences]
    return spans

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch

# Load pre-trained tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Load pre-trained model for sequence classification
model = BertForSequenceClassification.from_pretrained("bert-base-uncased", torch_dtype=torch.float16)

# Define function to classify spans
def classify_span(span_text):
    inputs = tokenizer(span_text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    logits = outputs.logits
    predicted_class_id = logits.argmax().item()
    return predicted_class_id

# Example usage
span_text = "Example text to classify"
predicted_class = classify_span(span_text)
print(f"Predicted class: {predicted_class}")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Predicted class: 1

# %%
def generate_output(text, spans, categories):
    annotations = []
    for start_char, end_char, span_text in spans:
        category_id = classify_span(span_text)
        category = categories[category_id]
        annotations.append({
            "start_char": start_char,
            "end_char": end_char,
            "category": category
        })
    return annotations

# %%
import json

# Path to your JSON file
file_path = '/content/drive/Shareddrives/BERTTask/dataset/dataset_en_official_test_nolabels.json'

# Load JSON data into a variable
with open(file_path, 'r') as file:
    data = json.load(file)

# Print the loaded data
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-f97b0b0c1627> in <cell line: 7>()
#       5
#       6 # Load JSON data into a variable
# ----> 7 with open(file_path, 'r') as file:
#       8     data = json.load(file)
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/Shareddrives/BERTTask/dataset/dataset_en_official_test_nolabels.json'

# %%
# Define categories
categories = ["VICTIM", "FACILITATOR", "AGENT", "CAMPAIGNER", "OBJECTIVE", "NEGATIVE_EFFECT"]

# Process each entry
outputs = []
for entry in data:
    text = entry["text"]
    spans = preprocess_text(text)
    # dic = {'id': entry['id'], 'annotations': []}
    annotations = generate_output(text, spans, categories)
    output_entry = {
        "id": entry["id"],
        "annotations": annotations
    }
    # print(output_entry)
    # for line in output_entry['annotations']:
    #   print(text[line['start_char']: line['end_char']])
    # print()
    print(output_entry)
    outputs.append(output_entry)

# Example output
# Out:
# {'id': '6742', 'annotations': [{'start_char': 0, 'end_char': 49, 'category': 'CAMPAIGNER'}, {'start_char': 50, 'end_char': 88, 'category': 'AGENT'}, {'start_char': 89, 'end_char': 133, 'category': 'AGENT'}, {'start_char': 134, 'end_char': 222, 'category': 'CAMPAIGNER'}, {'start_char': 223, 'end_char': 354, 'category': 'CAMPAIGNER'}, {'start_char': 355, 'end_char': 374, 'category': 'AGENT'}, {'start_char': 375, 'end_char': 388, 'category': 'AGENT'}, {'start_char': 389, 'end_char': 416, 'category': 'AGENT'}]}
# {'id': '10596', 'annotations': [{'start_char': 0, 'end_char': 178, 'category': 'AGENT'}, {'start_char': 179, 'end_char': 184, 'category': 'NEGATIVE_EFFECT'}, {'start_char': 185, 'end_char': 234, 'category': 'CAMPAIGNER'}]}
# {'id': '482', 'annotations': [{'start_char': 0, 'end_char': 52, 'category': 'AGENT'}, {'start_char': 53, 'end_char': 344, 'category': 'CAMPAIGNER'}, {'start_char': 345, 'end_char': 360, 'category': 'AGENT'}, {'start_char': 361, 'end_char': 376, 'category': 'CAMPAIGNER'}, {'start_char': 377, 'end_char': 649, 'category': 'CAMPAIGNER'}, {'start_char': 650, 'end_char': 766, 'category': 'CAMPAIGNER'}]}
# {'id': '1613', 'annotations': [{'start_char': 0, 'end_char': 156, 'category': 'CAMPAIGNER'}, {'start_char': 157, 'end_char': 412, 'category': 'CAMPAIGNER'}, {'start_char': 413, 'end_char': 436, 'category': 'AGENT'}, {'start_char': 437, 'end_char': 537, 'category': 'NEGATIVE_EFFECT'}, {'start_char': 538, 'end_char': 560, 'category': 'AGENT'}, {'start_char': 561, 'end_char': 565, 'category': 'AGENT'}, {'start_char': 566, 'end_char': 583, 'category': 'AGENT'}]}
# {'id': '10549', 'annotations': [{'start_char': 0, 'end_char': 71, 'category': 'CAMPAIGNER'}, {'start_char': 72, 'end_char': 235, 'category': 'AGENT'}, {'start_char': 236, 'end_char': 245, 'category': 'AGENT'}, {'start_char': 246, 'end_char': 259, 'category': 'AGENT'}, {'start_char': 260, 'end_char': 275, 'category': 'AGENT'}]}
# {'id': '1221', 'annotations': [{'start_char': 0, 'end_char': 77, 'category': 'CAMPAIGNER'}, {'start_char': 78, 'end_char': 153, 'category': 'CAMPAIGNER'}, {'start_char': 154, 'end_char': 329, 'category': 'CAMPAIGNER'}, {'start_char': 330, 'end_char': 400, 'category': 'CAMPAIGNER'}, {'start_char': 401, 'end_char': 469, 'category': 'AGENT'}, {'start_char': 470, 'end_char': 544, 'category': 'AGENT'}, {'start_char': 545, 'end_char': 674, 'category': 'CAMPAIGNER'}, {'start_char': 675, 'end_char': 850, 'category': 'CAMPAIGNER'}, {'start_char': 851, 'end_char': 895, 'category': 'AGENT'}, {'start_char': 896,
# {'id': '13081', 'annotations': [{'start_char': 0, 'end_char': 300, 'category': 'AGENT'}, {'start_char': 301, 'end_char': 306, 'category': 'AGENT'}, {'start_char': 307, 'end_char': 450, 'category': 'CAMPAIGNER'}]}
# {'id': '10807', 'annotations': [{'start_char': 0, 'end_char': 147, 'category': 'CAMPAIGNER'}, {'start_char': 148, 'end_char': 232, 'category': 'AGENT'}, {'start_char': 233, 'end_char': 301, 'category': 'CAMPAIGNER'}, {'start_char': 302, 'end_char': 378, 'category': 'CAMPAIGNER'}, {'start_char': 379, 'end_char': 392, 'category': 'AGENT'}]}
# {'id': '4173', 'annotations': [{'start_char': 0, 'end_char': 81, 'category': 'CAMPAIGNER'}, {'start_char': 82, 'end_char': 148, 'category': 'CAMPAIGNER'}, {'start_char': 149, 'end_char': 158, 'category': 'AGENT'}, {'start_char': 159, 'end_char': 252, 'category': 'AGENT'}, {'start_char': 253, 'end_char': 329, 'category': 'AGENT'}]}
# {'id': '1992', 'annotations': [{'start_char': 0, 'end_char': 176, 'category': 'AGENT'}, {'start_char': 177, 'end_char': 282, 'category': 'CAMPAIGNER'}, {'start_char': 283, 'end_char': 378, 'category': 'CAMPAIGNER'}, {'start_char': 379, 'end_char': 469, 'category': 'AGENT'}, {'start_char': 470, 'end_char': 506, 'category': 'AGENT'}, {'start_char': 507, 'end_char': 583, 'category': 'AGENT'}, {'start_char': 584, 'end_char': 626, 'category': 'CAMPAIGNER'}, {'start_char': 627, 'end_char': 641, 'category': 'AGENT'}]}
# {'id': '5130', 'annotations': [{'start_char': 0, 'end_char': 13, 'category': 'AGENT'}, {'start_char': 14, 'end_char': 267, 'category': 'CAMPAIGNER'}, {'start_char': 268, 'end_char': 286, 'category': 'AGENT'}, {'start_char': 287, 'end_char': 425, 'category': 'AGENT'}]}
# {'id': '10531', 'annotations': [{'start_char': 0, 'end_char': 299, 'category': 'CAMPAIGNER'}, {'start_char': 300, 'end_char': 317, 'category': 'AGENT'}, {'start_char': 318, 'end_char': 336, 'category': 'AGENT'}, {'start_char': 337, 'end_char': 345, 'category': 'AGENT'}]}
# {'id': '3602', 'annotations': [{'start_char': 0, 'end_char': 96, 'category': 'CAMPAIGNER'}]}
# {'id': '10960', 'annotations': [{'start_char': 0, 'end_char': 32, 'category': 'AGENT'}, {'start_char': 32, 'end_char': 120, 'category': 'CAMPAIGNER'}, {'start_char': 121, 'end_char': 179, 'category': 'CAMPAIGNER'}, {'start_char': 180, 'end_char': 202, 'category': 'AGENT'}, {'start_char': 203, 'end_char': 274, 'category': 'CAMPAIGNER'}]}
# {'id': '1418', 'annotations': [{'start_char': 0, 'end_char': 154, 'category': 'CAMPAIGNER'}]}
# {'id': '184', 'annotations': [{'start_char': 0, 'end_char': 524, 'category': 'CAMPAIGNER'}, {'start_char': 525, 'end_char': 627, 'category': 'CAMPAIGNER'}, {'start_char': 628, 'end_char': 707, 'category': 'AGENT'}, {'start_char': 708, 'end_char': 735, 'category': 'AGENT'}]}
# {'id': '1820', 'annotations': [{'start_char': 0, 'end_char': 106, 'category': 'CAMPAIGNER'}, {'start_char': 107, 'end_char': 207, 'category': 'CAMPAIGNER'}, {'start_char': 208, 'end_char': 323, 'category': 'CAMPAIGNER'}, {'start_char': 324, 'end_char': 351, 'category': 'AGENT'}, {'start_char': 352, 'end_char': 448, 'category': 'AGENT'}]}
# {'id': '5039', 'annotations': [{'start_char': 0, 'end_char': 332, 'category': 'CAMPAIGNER'}, {'start_char': 333, 'end_char': 425, 'category': 'AGENT'}]}
# ...
# {'id': '10707', 'annotations': [{'start_char': 0, 'end_char': 93, 'category': 'AGENT'}, {'start_char': 94, 'end_char': 157, 'category': 'AGENT'}, {'start_char': 158, 'end_char': 163, 'category': 'AGENT'}, {'start_char': 164, 'end_char': 175, 'category': 'AGENT'}, {'start_char': 176, 'end_char': 181, 'category': 'NEGATIVE_EFFECT'}, {'start_char': 182, 'end_char': 231, 'category': 'CAMPAIGNER'}]}
# {'id': '4462', 'annotations': [{'start_char': 0, 'end_char': 201, 'category': 'CAMPAIGNER'}, {'start_char': 202, 'end_char': 220, 'category': 'AGENT'}, {'start_char': 221, 'end_char': 292, 'category': 'CAMPAIGNER'}]}
# {'id': '3430', 'annotations': [{'start_char': 0, 'end_char': 163, 'category': 'CAMPAIGNER'}, {'start_char': 164, 'end_char': 182, 'category': 'AGENT'}, {'start_char': 183, 'end_char': 315, 'category': 'AGENT'}]}
# {'id': '13122', 'annotations': [{'start_char': 0, 'end_char': 199, 'category': 'CAMPAIGNER'}, {'start_char': 200, 'end_char': 273, 'category': 'CAMPAIGNER'}]}
# {'id': '5177', 'annotations': [{'start_char': 0, 'end_char': 93, 'category': 'CAMPAIGNER'}, {'start_char': 94, 'end_char': 227, 'category': 'CAMPAIGNER'}]}
# {'id': '6176', 'annotations': [{'start_char': 0, 'end_char': 107, 'category': 'CAMPAIGNER'}, {'start_char': 108, 'end_char': 257, 'category': 'AGENT'}]}
# {'id': '10710', 'annotations': [{'start_char': 0, 'end_char': 157, 'category': 'CAMPAIGNER'}, {'start_char': 158, 'end_char': 217, 'category': 'AGENT'}, {'start_char': 218, 'end_char': 342, 'category': 'CAMPAIGNER'}, {'start_char': 343, 'end_char': 361, 'category': 'AGENT'}, {'start_char': 362, 'end_char': 521, 'category': 'CAMPAIGNER'}, {'start_char': 522, 'end_char': 553, 'category': 'AGENT'}, {'start_char': 554, 'end_char': 635, 'category': 'AGENT'}]}
# {'id': '14010', 'annotations': [{'start_char': 0, 'end_char': 116, 'category': 'CAMPAIGNER'}, {'start_char': 117, 'end_char': 155, 'category': 'CAMPAIGNER'}, {'start_char': 156, 'end_char': 370, 'category': 'VICTIM'}, {'start_char': 370, 'end_char': 401, 'category': 'AGENT'}]}
# {'id': '12344', 'annotations': [{'start_char': 0, 'end_char': 27, 'category': 'AGENT'}, {'start_char': 28, 'end_char': 173, 'category': 'CAMPAIGNER'}, {'start_char': 174, 'end_char': 284, 'category': 'CAMPAIGNER'}]}
_char': 1173, 'end_char': 1178, 'category': 'AGENT'}, {'start_char': 1179, 'end_char': 1195, 'category': 'AGENT'}, {'start_char': 1196, 'end_char': 1264, 'category': 'AGENT'}, {'start_char': 1265, 'end_char': 1271, 'category': 'AGENT'}, {'start_char': 1272, 'end_char': 1277, 'category': 'AGENT'}, {'start_char': 1278, 'end_char': 1283, 'category': 'AGENT'}, {'start_char': 1284, 'end_char': 1300, 'category': 'AGENT'}, {'start_char': 1301, 'end_char': 1380, 'category': 'CAMPAIGNER'}, {'start_char': 1381, 'end_char': 1387, 'category': 'AGENT'}, {'start_char': 1388, 'end_char': 1393, 'category': 'AGENT'}, {'start_char': 1394, 'end_char': 1399, 'category': 'AGENT'}, {'start_char': 1400, 'end_char': 1497, 'category': 'AGENT'}, {'start_char': 1498, 'end_char': 1504, 'category': 'AGENT'}, {'start_char': 1505, 'end_char': 1510, 'category': 'AGENT'}, {'start_char': 1511, 'end_char': 1516, 'category': 'AGENT'}, {'start_char': 1517, 'end_char': 1533, 'category': 'AGENT'}, {'start_char': 1534, 'end_char': 1620, 'category': 'AGENT'}, {'start_char': 1621, 'end_char': 1627, 'category': 'AGENT'}, {'start_char': 1628, 'end_char': 1633, 'category': 'AGENT'}, {'start_char': 1634, 'end_char': 1639, 'category': 'AGENT'}, {'start_char': 1640, 'end_char': 1730, 'category': 'AGENT'}, {'start_char': 1731, 'end_char': 1737, 'category': 'AGENT'}, {'start_char': 1738, 'end_char': 1743, 'category': 'AGENT'}, {'start_char': 1744, 'end_char': 1749, 'category': 'AGENT'}, {'start_char': 1750, 'end_char': 1764, 'category': 'AGENT'}, {'start_char': 1765, 'end_char': 1897, 'category': 'AGENT'}, ...
# {'id': '12099', 'annotations': [{'start_char': 0, 'end_char': 217, 'category': 'CAMPAIGNER'}, {'start_char': 217, 'end_char': 318, 'category': 'AGENT'}, {'start_char': 318, 'end_char': 398, 'category': 'CAMPAIGNER'}, {'start_char': 399, 'end_char': 456, 'category': 'CAMPAIGNER'}, {'start_char': 457, 'end_char': 496, 'category': 'AGENT'}, {'start_char': 496, 'end_char': 521, 'category': 'AGENT'}]}
# {'id': '10705', 'annotations': [{'start_char': 0, 'end_char': 199, 'category': 'AGENT'}, {'start_char': 200, 'end_char': 211, 'category': 'AGENT'}, {'start_char': 212, 'end_char': 217, 'category': 'NEGATIVE_EFFECT'}, {'start_char': 218, 'end_char': 234, 'category': 'AGENT'}]}

# %%
with open('drive/Shareddrives/BERTTask/kaprov_task2_en.json', 'w') as fp:
  fp.write(str(outputs))

# %%
json_file_path = 'drive/Shareddrives/BERTTask/kaprov_task2_en.json'
outputs.to_json(json_file_path, orient='records', lines=False)

print(f"DataFrame has been written to {json_file_path}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-78b365692137> in <cell line: 2>()
#       1 json_file_path = 'drive/Shareddrives/BERTTask/kaprov_task2_en.json'
# ----> 2 outputs.to_json(json_file_path, orient='records', lines=False)
#       3
#       4 print(f"DataFrame has been written to {json_file_path}")
#
# AttributeError: 'list' object has no attribute 'to_json'
